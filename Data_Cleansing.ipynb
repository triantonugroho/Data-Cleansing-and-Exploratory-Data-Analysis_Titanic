# %% [markdown]
# #Data Cleansing

# %% [markdown]
# import libraary

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# make a data frame and load the dataset

# %% [markdown]
# the dataset used here is Titanic.csv

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-dcdb5d1d-9b2e-4b44-9803-407a9cc6e6c1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dcdb5d1d-9b2e-4b44-9803-407a9cc6e6c1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Titanic.csv to Titanic.csv
# ...

# %%
df = pd.read_csv('Titanic.csv')

# %% [markdown]
# show the loaded dataset

# %% [markdown]
# head default is 5 first rows

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Show the first 10 rows of data

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# Show the last 10 rows of data

# %% [markdown]
# tail default is the last 5 rows

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# Take a look at the data condition

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# #Column Age

# %% [markdown]
# show the column visualization

# %% [markdown]
# to describe Age variable

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %% [markdown]
# to see the proportion of Age variable

# %%
df['Age'].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: Age, Length: 88, dtype: int64

# %%
df['Age'].plot(kind='hist');

# %% [markdown]
# because the Age coulumn shows skewness, so we have to apply an imputation with median

# %%
val =df['Age'].median()
df['Age'] = df['Age'].fillna(val)

# %% [markdown]
# Show dataset info to see if the Age column is imputationed
#
# Now, the Age column is changed at its sum

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# #Column Cabin

# %% [markdown]
# the sum of data entry is 891 yet the Cabin Column is 204
#
# it means there must be NULL in the Cabin column
#
# show Cabin column proportion

# %%
df['Cabin'].value_counts()
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: Cabin, Length: 147, dtype: int64

# %% [markdown]
# It showed that Cabin column value has too much unique data
#
# and also the Cabin clumn info is not quite informative to describe survived data
#
# So we better remove the Cabin column

# %%
df.drop('Cabin', axis=1, inplace = True)

# %% [markdown]
# Show dataset info to see whether the Cabin column is removed
#
# now, the Cabin column is no longer exist

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %% [markdown]
# #Column Embarked

# %% [markdown]
# the sum of data entry is 891 yet the Embarked Column is 889
#
# it means there must be NULL in the EMbarked column
#
# we take a look where the NULL data is

# %%
df.Embarked[df.Embarked.isnull()]
# Out:
# 61     NaN
# 829    NaN
# Name: Embarked, dtype: object

# %% [markdown]
# show the Embarked column proportion
#
# Embarked column is categorical data

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %% [markdown]
# we will apply an imputation on EMbarked column
#
# so we check the data type of the EMbarked column first
#
# Embarked column is categorical data so the imputation is using mode
#
# from the proportion of EMbarked column, S appeared the most. so S is the mode

# %%
val = df.Embarked.mode().values[0]
df['Embarked'] = df.Embarked.fillna(val)

# %% [markdown]
# after being imputationed, it showed that the proportion is changed already

# %%
df.Embarked.value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %% [markdown]
# the 2 missing values are added to the S (mode)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %% [markdown]
# There's no more missing value

# %% [markdown]
# #Column SibSp dan Column Parch

# %% [markdown]
# We will do data manipulation
#
# manipulation here doesn't mean changing the data value
#
# but to ease a machine to read data
#
# SibSp column (sibling Spouse) ia a column that state the number of siblings or partner came with the pessenger
#
# Parch(Parent Childern) column is a column that state the number of parents or children came with the pessenger
#
# we will make a new column that shows whether the pessenger is alone or coming with their family

# %%
df['Alone'] = df['SibSp'] + df['Parch']

# %%
df['Alone'][df['Alone']>0]='With Family'
df['Alone'][df['Alone']==0]='With Family'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# shows the new data

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked        Alone
# 0      0         A/5 21171   7.2500        S  With Family
# 1      0          PC 17599  71.2833        C  With Family
# 2      0  STON/O2. 3101282   7.9250        S  With Family
# 3      0            113803  53.1000        S  With Family
# ...

# %% [markdown]
# #The realtion between sex column dan survived column

# %% [markdown]
# let's see the survived Sex column proposal

# %%
df.Sex[df['Survived']==1].value_counts()
# Out:
# female    233
# male      109
# Name: Sex, dtype: int64

# %% [markdown]
# show the survived Sex column visualization

# %%
df.Sex[df['Survived']==1].value_counts().plot(kind='bar');

# %% [markdown]
# compare it with the Sex column which is not survived

# %%
df.Sex[df['Survived']==0].value_counts()
# Out:
# male      468
# female     81
# Name: Sex, dtype: int64

# %% [markdown]
# show the visualization of Sex column which is not survived

# %%
df.Sex[df['Survived']==0].value_counts().plot(kind='bar');
